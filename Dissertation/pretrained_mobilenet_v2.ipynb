# %%
# TODO: Make all necessary imports.
# !pip install -q tqdm==4.28.1

# !pip install tensorflow_datasets
# !pip install tensorflow_hub
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub
tfds.disable_progress_bar()
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
dataset, dataset_info = tfds.load('oxford_flowers102', with_info=True, as_supervised=True)
dataset_info
# TODO: Create a training set, a validation set and a test set.
test_set, training_set, validation_set = dataset['test'], dataset['train'], dataset['validation']

# %%
dataset
# Out:
# {'train': <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>,
#  'test': <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>,
#  'validation': <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>}

# %%
# TODO: Get the number of examples in each set from the dataset info.
num_training_examples = 0
num_validation_examples = 0
num_test_examples = 0

for example in training_set:
    num_training_examples += 1

for example in validation_set:
    num_validation_examples += 1

for example in test_set:
    num_test_examples += 1

print('Total Number of Training Images: {}'.format(num_training_examples))
print('Total Number of Validation Images: {}'.format(num_validation_examples))
print('Total Number of Test Images: {} \n'.format(num_test_examples))
# TODO: Get the number of classes in the dataset from the dataset info.
num_classes = dataset_info.features['label'].num_classes
print('Total Number of Classes: {}'.format(num_classes))
# Out:
# Total Number of Training Images: 1020
# Total Number of Validation Images: 1020
# Total Number of Test Images: 6149
#
# Total Number of Classes: 102

# %%
training_set.take(1)
# Out:
# <TakeDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>

# %%
for image, label in training_set.take(1):
  break
image = image.numpy()
plt.figure()
plt.imshow(image, cmap=plt.cm.binary)
plt.title('corresponding image label {}'.format(label))
plt.colorbar()
plt.grid(False)
plt.show()

# %%
# TODO: Create a pipeline for each set.
IMAGE_RES = 224

def format_image(image, label):
    image = tf.image.resize(image, (IMAGE_RES, IMAGE_RES))/255.0
    return image, label

BATCH_SIZE = 32

train_batches = training_set.cache().shuffle(num_training_examples//4).map(format_image).batch(BATCH_SIZE).prefetch(1)

validation_batches = validation_set.cache().map(format_image).batch(BATCH_SIZE).prefetch(1)

test_batches = test_set.cache().map(format_image).batch(BATCH_SIZE).prefetch(1)

# %%
# test_batches = test_set.cache().map(format_image)
# batch = test_batches.batch(BATCH_SIZE).prefetch(1)

# %%
# TODO: Build and train your network.
from tensorflow.keras import layers
# Create a Feature Extractor
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(URL,
                                   input_shape=(IMAGE_RES, IMAGE_RES, 3))
# Freeze the Pre-Trained Model
feature_extractor.trainable = False
# Attach a classification head
model = tf.keras.Sequential([
  feature_extractor,
  layers.Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 102)               130662
# =================================================================
# Total params: 2,388,646
# Trainable params: 130,662
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
print('Is there a GPU Available:', tf.test.is_gpu_available())
# Out:
# Is there a GPU Available: True

# %%
model.compile(
  optimizer='adam',
  loss='sparse_categorical_crossentropy',
  metrics=['accuracy'])

EPOCHS = 20

# Stop training when there is no improvement in the validation loss for 5 consecutive epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(train_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 32/32 [==============================] - 8s 50ms/step - loss: 4.2614 - accuracy: 0.1108 - val_loss: 3.1016 - val_accuracy: 0.3657
# Epoch 2/20
# 32/32 [==============================] - 1s 34ms/step - loss: 2.0508 - accuracy: 0.7000 - val_loss: 2.0064 - val_accuracy: 0.6549
# Epoch 3/20
# 32/32 [==============================] - 1s 34ms/step - loss: 1.0904 - accuracy: 0.8922 - val_loss: 1.5425 - val_accuracy: 0.7049
# Epoch 4/20
# 32/32 [==============================] - 1s 34ms/step - loss: 0.6713 - accuracy: 0.9578 - val_loss: 1.3042 - val_accuracy: 0.7490
# Epoch 5/20
# 32/32 [==============================] - 1s 35ms/step - loss: 0.4493 - accuracy: 0.9775 - val_loss: 1.1592 - val_accuracy: 0.7755
# Epoch 6/20
# 32/32 [==============================] - 1s 34ms/step - loss: 0.3168 - accuracy: 0.9892 - val_loss: 1.0760 - val_accuracy: 0.7794
# Epoch 7/20
# 32/32 [==============================] - 1s 33ms/step - loss: 0.2375 - accuracy: 0.9980 - val_loss: 1.0060 - val_accuracy: 0.7980
# Epoch 8/20
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1813 - accuracy: 0.9980 - val_loss: 0.9626 - val_accuracy: 0.7971
# Epoch 9/20
# 32/32 [==============================] - 1s 38ms/step - loss: 0.1462 - accuracy: 1.0000 - val_loss: 0.9276 - val_accuracy: 0.8000
# Epoch 10/20
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1199 - accuracy: 1.0000 - val_loss: 0.8997 - val_accuracy: 0.7990
# Epoch 11/20
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0999 - accuracy: 1.0000 - val_loss: 0.8790 - val_accuracy: 0.8029
# Epoch 12/20
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0857 - accuracy: 1.0000 - val_loss: 0.8568 - val_accuracy: 0.8049
# Epoch 13/20
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 0.8418 - val_accuracy: 0.8069
# Epoch 14/20
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0644 - accuracy: 1.0000 - val_loss: 0.8288 - val_accuracy: 0.8059
# Epoch 15/20
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.8153 - val_accuracy: 0.8059
# Epoch 16/20
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.8055 - val_accuracy: 0.8088
# Epoch 17/20
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0455 - accuracy: 1.0000 - val_loss: 0.7965 - val_accuracy: 0.8108
# Epoch 18/20
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 0.7870 - val_accuracy: 0.8108
# Epoch 19/20
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.7800 - val_accuracy: 0.8108
# Epoch 20/20
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.7731 - val_accuracy: 0.8118

# %%
model.evaluate(test_batches)
# Out:
# 193/193 [==============================] - 4s 18ms/step - loss: 0.8994 - accuracy: 0.7787
# [0.899378776550293, 0.7786632180213928]
